# %%
import dpcv.modeling.networks.cr_net
import wandb
import random
import yaml
from easydict import EasyDict as CfgNode

# config = r'/home/hyojinju/DeepPersonality/config/unified_frame_images/04_crnet.yaml'
# with open(config, 'r') as f:
#     yaml_cfg = CfgNode(yaml.safe_load(f))

# # start a new wandb run to track this script
# wandb.init(
#     # set the wandb project where this run will be logged
#     project="cr_net_training",
    
#     # track hyperparameters and run metadata
#     config={
#     "learning_rate": yaml_cfg.SOLVER.LR_INIT,
#     "architecture": yaml_cfg.MODEL.NAME,
#     "epochs": yaml_cfg.TRAIN.MAX_EPOCH,
#     }
# )


# !python script/run_exp.py \
    -c /home/hyojinju/DeepPersonality/config/unified_frame_images/04_crnet_lc.yaml \
    --set MODEL.NAME crnet_lc_model \
    DATA_LOADER.NAME crnet_lc_data_loader \
    TRAIN.TRAINER CRNetTrainer2 \
    TRAIN.OUTPUT_DIR results/unified_frame_images/04_crnet_lc_v1
# Out:
# wandb: Currently logged in as: gywls0724 (dl2023_team1). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /home/hyojinju/DeepPersonality/wandb/run-20231204_060850-xr9cihvv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run young-forest-16
# wandb: ⭐️ View project at https://wandb.ai/dl2023_team1/cr_net_training
# wandb: 🚀 View run at https://wandb.ai/dl2023_team1/cr_net_training/runs/xr9cihvv
# {
#     "DATA":{
#         "ROOT":"/data1/ChaLearnLC/",
#         "SESSION":"talk",
#         "TEST_AUD_DATA":"voice_data/voice_librosa/test_data",
#         "TEST_IMG_ALBEDO_DATA":"test_data_face_decomposed/albedo",
#         "TEST_IMG_DATA":"test_data",
#         "TEST_IMG_FACE_DATA":"image_data/test_data_face",
#         "TEST_IMG_SHADING_DATA":"test_data_face_decomposed/shading",
#         "TEST_LABEL_DATA":"annotation/annotation_test.pkl",
# ...
