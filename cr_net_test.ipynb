# %%
import dpcv.modeling.networks.cr_net
import wandb
import random
import yaml
from easydict import EasyDict as CfgNode

# config = r'/home/hyojinju/DeepPersonality/config/unified_frame_images/04_crnet.yaml'
# with open(config, 'r') as f:
#     yaml_cfg = CfgNode(yaml.safe_load(f))

# # start a new wandb run to track this script
# wandb.init(
#     # set the wandb project where this run will be logged
#     project="cr_net_training",
    
#     # track hyperparameters and run metadata
#     config={
#     "learning_rate": yaml_cfg.SOLVER.LR_INIT,
#     "architecture": yaml_cfg.MODEL.NAME,
#     "epochs": yaml_cfg.TRAIN.MAX_EPOCH,
#     }
# )


# !python script/run_exp.py \
    -c /home/hyojinju/DeepPersonality/config/unified_frame_images/04_crnet_abl.yaml \
    --set MODEL.NAME crnet_model \
    DATA_LOADER.NAME crnet_data_loader \
    TRAIN.TRAINER CRNetTrainer2 \
    TRAIN.OUTPUT_DIR results/unified_frame_images/04_crnet_abl
# Out:
# wandb: Currently logged in as: gywls0724 (dl2023_team1). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /home/hyojinju/DeepPersonality/wandb/run-20231130_055400-vbpwjlgd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eager-flower-7
# wandb: ⭐️ View project at https://wandb.ai/dl2023_team1/cr_net_training
# wandb: 🚀 View run at https://wandb.ai/dl2023_team1/cr_net_training/runs/vbpwjlgd
# {
#     "DATA":{
#         "ROOT":"datasets/",
#         "SESSION":"talk",
#         "TEST_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/test_data",
#         "TEST_IMG_DATA":"ChaLearn2016_tiny/test_data",
#         "TEST_IMG_FACE_DATA":"ChaLearn2016_tiny/test_data_face",
#         "TEST_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_test.pkl",
#         "TRAIN_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/train_data",
#         "TRAIN_IMG_DATA":"ChaLearn2016_tiny/train_data",
#         "TRAIN_IMG_FACE_DATA":"ChaLearn2016_tiny/train_data_face",
#         "TRAIN_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_training.pkl",
#         "TYPE":"frame",
#         "VALID_AUD_DATA":"ChaLearn2016_tiny/voice_data/voice_librosa/valid_data",
#         "VALID_IMG_DATA":"ChaLearn2016_tiny/valid_data",
#         "VALID_IMG_FACE_DATA":"ChaLearn2016_tiny/valid_data_face",
#         "VALID_LABEL_DATA":"ChaLearn2016_tiny/annotation/annotation_validation.pkl",
#         "VA_DATA":"va_data/cropped_aligned",
#         "VA_ROOT":"datasets",
#         "VA_TRAIN_LABEL":"va_data/va_label/VA_Set/Train_Set",
#         "VA_VALID_LABEL":"va_data/va_label/VA_Set/Validation_Set"
#     },
#     "DATA_LOADER":{
#         "DATASET":"",
#         "DROP_LAST":true,
#         "NAME":"crnet_data_loader",
#         "NUM_WORKERS":4,
#         "SECOND_STAGE":{
#             "METHOD":"",
#             "TYPE":""
#         },
#         "SHUFFLE":true,
#         "TRAIN_BATCH_SIZE":10,
#         "TRANSFORM":"crnet_frame_face_transform",
#         "VALID_BATCH_SIZE":10
#     },
#     "LOSS":{
#         "NAME":"crnet_loss_func"
#     },
#     "MODEL":{
#         "NAME":"crnet_model",
#         "NUM_CLASS":5,
#         "PRETRAIN":false,
#         "RETURN_FEATURE":false,
#         "SPECTRUM_CHANNEL":50
#     },
#     "SOLVER":{
#         "BETA_1":0.5,
#         "BETA_2":0.999,
#         "FACTOR":0.1,
#         "LR_INIT":0.002,
#         "MILESTONE":[
#             80,
#             90
#         ],
#         "MOMENTUM":0.9,
#         "NAME":"crnet_solver",
#         "RESET_LR":false,
#         "SCHEDULER":"crnet_multi_step_scale",
#         "WEIGHT_DECAY":0.005
#     },
#     "TEST":{
#         "COMPUTE_CCC":true,
#         "COMPUTE_PCC":true,
#         "FULL_TEST":false,
#         "SAVE_DATASET_OUTPUT":"",
#         "TEST_ONLY":false,
#         "WEIGHT":""
#     },
#     "TRAIN":{
#         "LOG_INTERVAL":10,
#         "MAX_EPOCH":100,
#         "OUTPUT_DIR":"results/unified_frame_images/04_crnet",
#         "PRE_TRAINED_MODEL":null,
#         "RESUME":"",
#         "START_EPOCH":0,
#         "TRAINER":"CRNetTrainer2",
#         "VALID_INTERVAL":1
#     }
# }
# Training: classification phrase, learning rate:0.002
# /home/hyojinju/anaconda3/envs/crnet/lib/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1699449181081/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# only test regression accuracy
# /home/hyojinju/anaconda3/envs/crnet/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Training: classification phrase, learning rate:0.002
# only test regression accuracy
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[003/100] Train Mean_Acc: 29.28% Valid Mean_Acc:0.00% OCEAN_ACC:[0. 0. 0. 0. 0.]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[004/100] Train Mean_Acc: 77.23% Valid Mean_Acc:3.83% OCEAN_ACC:[0.         0.11464014 0.         0.         0.07673697]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[005/100] Train Mean_Acc: 82.07% Valid Mean_Acc:82.83% OCEAN_ACC:[0.8197118  0.84820986 0.78101003 0.86140835 0.8313204 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[006/100] Train Mean_Acc: 78.36% Valid Mean_Acc:70.80% OCEAN_ACC:[0.66650414 0.6903919  0.72806096 0.71897745 0.7362993 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[007/100] Train Mean_Acc: 81.80% Valid Mean_Acc:61.59% OCEAN_ACC:[0.6057013  0.613798   0.62741244 0.59959805 0.63288903]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[008/100] Train Mean_Acc: 82.03% Valid Mean_Acc:10.66% OCEAN_ACC:[0.         0.31021297 0.         0.16778488 0.05523957]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[009/100] Train Mean_Acc: 82.60% Valid Mean_Acc:36.73% OCEAN_ACC:[0.38958198 0.39081496 0.41489124 0.3147021  0.3266748 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[010/100] Train Mean_Acc: 83.54% Valid Mean_Acc:52.17% OCEAN_ACC:[0.5698673  0.5292238  0.6402664  0.43315667 0.43616253]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[011/100] Train Mean_Acc: 85.48% Valid Mean_Acc:85.58% OCEAN_ACC:[0.86746013 0.84138787 0.8215325  0.9110744  0.8372966 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[012/100] Train Mean_Acc: 86.06% Valid Mean_Acc:89.11% OCEAN_ACC:[0.91167396 0.87626064 0.8812993  0.90440214 0.8817693 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[013/100] Train Mean_Acc: 85.64% Valid Mean_Acc:77.68% OCEAN_ACC:[0.81579006 0.77154607 0.789398   0.77982396 0.7272645 ]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch

#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[078/100] Train Mean_Acc: 86.91% Valid Mean_Acc:82.47% OCEAN_ACC:[0.8541784  0.7034013  0.8549912  0.8580566  0.85279536]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[079/100] Train Mean_Acc: 86.99% Valid Mean_Acc:83.32% OCEAN_ACC:[0.842922   0.8526837  0.81262994 0.8436021  0.81422174]
#
# Training: regression phrase, learning rate:0.002
# Valid: Epoch[080/100] Train Mean_Acc: 86.57% Valid Mean_Acc:88.39% OCEAN_ACC:[0.88731456 0.8797168  0.87730384 0.8955955  0.8797458 ]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[081/100] Train Mean_Acc: 86.03% Valid Mean_Acc:88.89% OCEAN_ACC:[0.89122546 0.88385236 0.88388455 0.9001337  0.8856255 ]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[082/100] Train Mean_Acc: 87.15% Valid Mean_Acc:89.02% OCEAN_ACC:[0.89931715 0.88785887 0.87171566 0.9023341  0.88954425]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[083/100] Train Mean_Acc: 86.70% Valid Mean_Acc:88.90% OCEAN_ACC:[0.8929421 0.8872737 0.8713071 0.9018902 0.8915862]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[084/100] Train Mean_Acc: 86.70% Valid Mean_Acc:89.16% OCEAN_ACC:[0.89478445 0.8947257  0.870229   0.9077592  0.890509  ]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[085/100] Train Mean_Acc: 87.71% Valid Mean_Acc:88.85% OCEAN_ACC:[0.89460754 0.88906944 0.8687725  0.9010742  0.88900685]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[086/100] Train Mean_Acc: 87.69% Valid Mean_Acc:88.73% OCEAN_ACC:[0.900292   0.89207476 0.8616166  0.90245473 0.88025916]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[087/100] Train Mean_Acc: 87.45% Valid Mean_Acc:88.52% OCEAN_ACC:[0.8860026  0.8930016  0.8655355  0.89687455 0.88476795]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[088/100] Train Mean_Acc: 87.06% Valid Mean_Acc:88.51% OCEAN_ACC:[0.8893158  0.8893914  0.86497843 0.89681476 0.8848412 ]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[089/100] Train Mean_Acc: 86.52% Valid Mean_Acc:86.11% OCEAN_ACC:[0.8704215 0.8675634 0.8386166 0.8738097 0.8549281]
#
# Training: regression phrase, learning rate:0.0002
# Valid: Epoch[090/100] Train Mean_Acc: 87.20% Valid Mean_Acc:87.60% OCEAN_ACC:[0.876778   0.88556576 0.8526405  0.8984691  0.86663365]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[091/100] Train Mean_Acc: 86.53% Valid Mean_Acc:88.09% OCEAN_ACC:[0.8783384  0.89063376 0.86143124 0.8941572  0.8798113 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[092/100] Train Mean_Acc: 87.51% Valid Mean_Acc:87.87% OCEAN_ACC:[0.8755994  0.8894113  0.8608037  0.89233017 0.8752292 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[093/100] Train Mean_Acc: 87.50% Valid Mean_Acc:87.84% OCEAN_ACC:[0.87280655 0.8884618  0.8570579  0.8995968  0.87392676]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[094/100] Train Mean_Acc: 86.83% Valid Mean_Acc:86.54% OCEAN_ACC:[0.86710894 0.8717547  0.83963454 0.8915748  0.8568934 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[095/100] Train Mean_Acc: 87.27% Valid Mean_Acc:88.52% OCEAN_ACC:[0.88662606 0.89471054 0.8638257  0.8985301  0.8824778 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[096/100] Train Mean_Acc: 87.62% Valid Mean_Acc:87.60% OCEAN_ACC:[0.8920899  0.87644076 0.845705   0.9035908  0.8619853 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[097/100] Train Mean_Acc: 87.48% Valid Mean_Acc:86.39% OCEAN_ACC:[0.8664865  0.8752377  0.84159195 0.8756229  0.8604547 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[098/100] Train Mean_Acc: 86.16% Valid Mean_Acc:87.20% OCEAN_ACC:[0.87910295 0.88412845 0.84959877 0.8814936  0.8657824 ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[099/100] Train Mean_Acc: 86.90% Valid Mean_Acc:87.97% OCEAN_ACC:[0.88450557 0.8944091  0.8564706  0.88762075 0.875685  ]
#
# Training: regression phrase, learning rate:2e-05
# Valid: Epoch[100/100] Train Mean_Acc: 87.45% Valid Mean_Acc:88.40% OCEAN_ACC:[0.8848959  0.89749324 0.8633681  0.89347756 0.8805518 ]
#
# 11-30_05-55 done, best acc: 0.9089174270629883 in :32
# Test only mode
# test with model results/unified_frame_images/04_crnet/11-30_05-54/checkpoint_32.pkl
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  7.35it/s]
# mse: {'O': 0.035, 'C': 0.0188, 'E': 0.0186, 'A': 0.02, 'N': 0.0729} mean: 0.03310000151395798
# acc: [0.8730558  0.88658386 0.88804847 0.8781142  0.8173727 ] mean: 0.8686349987983704
# pcc: {'O': -0.2005, 'C': -0.1313, 'E': 0.0157, 'A': -0.1821, 'N': -0.2175} mean: -0.1432
# ccc: {'O': -0.1778, 'C': -0.0631, 'E': 0.0099, 'A': -0.0935, 'N': -0.207} mean: -0.1063
# wandb:
# wandb: Run history:
# wandb:          epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb: train_mean_acc ▁▇▇▇█▇▇██████████▇██████████████████████
# wandb: valid_mean_acc ▁▇▆▅█▁▁▇▆▄█▇██▃██▇▇▅█▇█▅█▁██▁█▅█████████
# wandb:
# wandb: Run summary:
# wandb:          epoch 100
# wandb: train_mean_acc 0.8745
# wandb: valid_mean_acc 0.88396
# wandb:
# wandb: 🚀 View run eager-flower-7 at: https://wandb.ai/dl2023_team1/cr_net_training/runs/vbpwjlgd
# wandb: ️⚡ View job at https://wandb.ai/dl2023_team1/cr_net_training/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjExOTgyMDQyNA==/version_details/v1
# wandb: Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231130_055400-vbpwjlgd/logs
